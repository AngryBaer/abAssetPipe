# %%
import json
import pandas as pd
import matplotlib.pyplot as plt


with open("P:/dev/abAssetPipe/data/dataset.json") as f:
    data = json.load(f)

df = pd.DataFrame(data)
df.head()

df.info()
df.describe(include='all')

plt.figure(figsize=(8,4))
df.plot.bar(x='name', y='count', legend=False)
plt.ylabel('Count')
plt.xlabel('Asset')
plt.title('Vertex Counts')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4 non-null      object
#  1   name         4 non-null      object
#  2   description  4 non-null      object
#  3   path         4 non-null      object
#  4   count        4 non-null      int64
#  5   bbox         4 non-null      object
#  6   tags         4 non-null      object
# dtypes: int64(1), object(6)
# memory usage: 356.0+ bytes
